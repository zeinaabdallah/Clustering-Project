# %% [markdown]
# # GUC Clustering Project

# %% [markdown]
# **Objective:**
# The objective of this project teach students how to apply clustering to real data sets
#
# The projects aims to teach student:
# * Which clustering approach to use
# * Compare between Kmeans, Hierarchal, DBScan, and Gaussian Mixtures
# * How to tune the parameters of each data approach
# * What is the effect of different distance functions (optional)
# * How to evaluate clustering approachs
# * How to display the output
# * What is the effect of normalizing the data
#
# Students in this project will use ready-made functions from Sklearn, plotnine, numpy and pandas

# %%
# if plotnine is not installed in Jupter then use the following command to install it

# %% [markdown]
# Running this project require the following imports

# %%
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sklearn.preprocessing as prep
from sklearn.datasets import make_blobs
from plotnine import *   
# StandardScaler is a function to normalize the data 
# You may also check MinMaxScaler and MaxAbsScaler 
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import AgglomerativeClustering

from sklearn.cluster import DBSCAN


from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture

from sklearn.metrics import silhouette_score
from yellowbrick.cluster import KElbowVisualizer


# %matplotlib inline

# %%
# helper function that allows us to display data in 2 dimensions an highlights the clusters
def display_cluster(X,km=[],num_clusters=0):
    color = 'brgcmyk'  #List colors
    alpha = 0.5  #color obaque
    s = 20
    if num_clusters == 0:
        plt.scatter(X[:,0],X[:,1],c = color[0],alpha = alpha,s = s)
    else:
        for i in range(num_clusters):
            plt.scatter(X[km.labels_==i,0],X[km.labels_==i,1],c = color[i],alpha = alpha,s=s)
            plt.scatter(km.cluster_centers_[i][0],km.cluster_centers_[i][1],c = color[i], marker = 'x', s = 100)

# %% [markdown]
# ## Multi Blob Data Set
# * The Data Set generated below has 6 cluster with varying number of users and varing densities
# * Cluster the data set below using

# %%
plt.rcParams['figure.figsize'] = [8,8]
sns.set_style("whitegrid")
sns.set_context("talk")

n_bins = 6  
centers = [(-3, -3), (0, 0), (5,2.5),(-1, 4), (4, 6), (9,7)]
Multi_blob_Data, y = make_blobs(n_samples=[100,150, 300, 400,300, 200], n_features=2, cluster_std=[1.3,0.6, 1.2, 1.7,0.9,1.7],
                  centers=centers, shuffle=False, random_state=42)
display_cluster(Multi_blob_Data)

# %% [markdown]
# ### Kmeans
# * Use Kmeans with different values of K to cluster the above data
# * Display the outcome of each value of K
# * Plot distortion function versus K and choose the approriate value of k
# * Plot the silhouette_score versus K and use it to choose the best K
# * Store the silhouette_score for the best K for later comparison with other clustering techniques.

# %%
score_km = []
for k in range(2,10):
    dftot = pd.DataFrame(Multi_blob_Data, columns=['col1','col2'])
    km = KMeans(n_clusters=k)
    y_km = km.fit_predict(dftot[['col1', 'col2']])
    dftot['cluster'] = y_km
    set_cluster = set(y_km)
    for c in set_cluster:
        df = dftot[dftot['cluster'] == c]
        mean = df[['col1', 'col2']].mean()
        plt.scatter(df['col1'], df['col2'], s=30, c=np.random.rand(3,).reshape(1,-1), marker='x', label='cluster 1')
        plt.scatter(mean['col1'], mean['col2'], c=np.random.rand(3,).reshape(1,-1), marker='+')
    plt.title(f"Clustering Data into {k} Clusters")
    plt.show()
    score_km.append(silhouette_score(dftot[['col1', 'col2']], y_km))

# %%
plt.title('Silhouette Score vs K Clusters')
plt.xlabel('Number of Clusters') 
plt.ylabel('Silhouette Score')
plt.plot(range(2,10),score_km)

# %%
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1, 10), timings=False)
visualizer.fit(dftot[['col1', 'col2']])
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# ### Hierarchal Clustering
# * Use AgglomerativeClustering function to  to cluster the above data
# * In the  AgglomerativeClustering change the following parameters
#     * Affinity (use euclidean, manhattan and cosine)
#     * Linkage( use average and single )
#     * Distance_threshold (try different)
# * For each of these trials plot the Dendograph , calculate the silhouette_score and display the resulting clusters
# * Find the set of paramters that would find result in the best silhouette_score and store this score for later comparison with other clustering techniques.
# * Record your observation

# %%
link = ['single','average']
aff = ['euclidean','manhattan','cosine']
for l in link:
    for a in aff:
        hierarchical_cluster = AgglomerativeClustering(n_clusters=4, affinity=a, linkage=l)
        labels = hierarchical_cluster.fit_predict(dftot)
        plt.scatter(dftot['col1'], dftot['col2'], c=labels,s=20)
        plt.title(f'Linkage: {l}, Affinity: {a}')
        plt.show()
# euc av 5
# man av 7
# cos av 0.4

# %% [markdown]
# ### DBScan
# * Use DBScan function to  to cluster the above data
# * In the  DBscan change the following parameters
#     * EPS (from 0.1 to 3)
#     * Min_samples (from 5 to 25)
# * Plot the silhouette_score versus the variation in the EPS and the min_samples
# * Plot the resulting Clusters in this case
# * Find the set of paramters that would find result in the best silhouette_score and store this score for later comparison with other clustering techniques.
# * Record your observations and comments

# %%
coords = dftot[['col1', 'col2']]
ss = StandardScaler()
coords = ss.fit_transform(coords)
db = DBSCAN(eps=0.9, min_samples=25)
db.fit(coords)
y_pred = db.fit_predict(coords)
plt.scatter(coords[:, 0], coords[:, 1], c=y_pred, cmap='Paired')
plt.title("DBSCAN")
plt.show()
for i in np.arange(0.1, 3.1, 0.1):
    for j in np.arange(5, 26, 0.69):
        ss = StandardScaler()
        coords = ss.fit_transform(coords)
        db = DBSCAN(eps=i, min_samples=j)
        db.fit(coords)
        y_pred = db.fit_predict(coords)
        if len(set(y_pred)) == 1:
            print(f'eps is {i}, minp is {j}, one cluster')
            continue
        print(f'eps is {i}, minp is {j}, {silhouette_score(dftot[["col1", "col2"]], y_pred)}')
# Out:
# eps is 0.1, minp is 5.0, -0.22593141283109558
# eps is 0.1, minp is 5.6899999999999995, -0.06459671057727064
# eps is 0.1, minp is 6.379999999999999, -0.03452253867946502
# eps is 0.1, minp is 7.0699999999999985, -0.07867425548966994
# eps is 0.1, minp is 7.759999999999998, -0.07867425548966994
# eps is 0.1, minp is 8.449999999999998, -0.21242742143183868
# eps is 0.1, minp is 9.139999999999997, -0.21755403274669122
# eps is 0.1, minp is 9.829999999999997, -0.21755403274669122
# eps is 0.1, minp is 10.519999999999996, -0.1812879022592816
# eps is 0.1, minp is 11.209999999999996, -0.20099060879904693
# eps is 0.1, minp is 11.899999999999995, -0.20099060879904693
# eps is 0.1, minp is 12.589999999999995, -0.2869309207181581
# eps is 0.1, minp is 13.279999999999994, -0.30043694025294193
# eps is 0.1, minp is 13.969999999999994, -0.30043694025294193
# eps is 0.1, minp is 14.659999999999993, -0.2675216111049305
# eps is 0.1, minp is 15.349999999999993, -0.2569622592618025
# eps is 0.1, minp is 16.039999999999992, -0.25418576491685296
# eps is 0.1, minp is 16.72999999999999, -0.25418576491685296
# eps is 0.1, minp is 17.41999999999999, -0.26341957942588257
# eps is 0.1, minp is 18.109999999999992, -0.19482062898514543
# eps is 0.1, minp is 18.79999999999999, -0.19482062898514543
# eps is 0.1, minp is 19.489999999999988, -0.20540201685327183
# eps is 0.1, minp is 20.17999999999999, -0.267957850361227
# eps is 0.1, minp is 20.86999999999999, -0.267957850361227
# eps is 0.1, minp is 21.559999999999988, -0.2736513806575077
# eps is 0.1, minp is 22.249999999999986, -0.2798916999014186
# eps is 0.1, minp is 22.939999999999987, -0.2798916999014186
# eps is 0.1, minp is 23.62999999999999, -0.2990445136895039
# eps is 0.1, minp is 24.319999999999986, -0.3164277635120941
# eps is 0.1, minp is 25.009999999999984, -0.21428135780945878
# eps is 0.1, minp is 25.699999999999985, -0.21428135780945878
# eps is 0.2, minp is 5.0, 0.2369788248940551
# eps is 0.2, minp is 5.6899999999999995, 0.23250239247727184
# eps is 0.2, minp is 6.379999999999999, 0.29646188679719804
# eps is 0.2, minp is 7.0699999999999985, 0.08725619361155121
# eps is 0.2, minp is 7.759999999999998, 0.08725619361155121
# eps is 0.2, minp is 8.449999999999998, 0.0774970475820788
# eps is 0.2, minp is 9.139999999999997, 0.20486064095505555
# eps is 0.2, minp is 9.829999999999997, 0.20486064095505555
# eps is 0.2, minp is 10.519999999999996, 0.09351499089579976
# eps is 0.2, minp is 11.209999999999996, 0.17582149092652669
# eps is 0.2, minp is 11.899999999999995, 0.17582149092652669
# eps is 0.2, minp is 12.589999999999995, 0.15711822944509427
# eps is 0.2, minp is 13.279999999999994, 0.04804382085314643
# eps is 0.2, minp is 13.969999999999994, 0.04804382085314643
# eps is 0.2, minp is 14.659999999999993, 0.08162912196969262
# eps is 0.2, minp is 15.349999999999993, 0.09299478984256651
# eps is 0.2, minp is 16.039999999999992, 0.029937258658128886
# eps is 0.2, minp is 16.72999999999999, 0.029937258658128886
# eps is 0.2, minp is 17.41999999999999, 0.01870303568061434
# eps is 0.2, minp is 18.109999999999992, 0.15390903072481765
# eps is 0.2, minp is 18.79999999999999, 0.15390903072481765
# eps is 0.2, minp is 19.489999999999988, 0.21696426888110856
# eps is 0.2, minp is 20.17999999999999, 0.21308065178090702
# eps is 0.2, minp is 20.86999999999999, 0.21308065178090702
# eps is 0.2, minp is 21.559999999999988, 0.20176929527351667
# eps is 0.2, minp is 22.249999999999986, 0.19058005735451164
# eps is 0.2, minp is 22.939999999999987, 0.19058005735451164
# eps is 0.2, minp is 23.62999999999999, 0.1795278518959697
# eps is 0.2, minp is 24.319999999999986, 0.1722430299384935
# eps is 0.2, minp is 25.009999999999984, 0.1634831389785759
# eps is 0.2, minp is 25.699999999999985, 0.1634831389785759
# eps is 0.30000000000000004, minp is 5.0, 0.3880513251024352
# eps is 0.30000000000000004, minp is 5.6899999999999995, 0.38653496102603263
# eps is 0.30000000000000004, minp is 6.379999999999999, 0.3946219635757616
# eps is 0.30000000000000004, minp is 7.0699999999999985, 0.388628480339273
# eps is 0.30000000000000004, minp is 7.759999999999998, 0.388628480339273
# eps is 0.30000000000000004, minp is 8.449999999999998, 0.36307110876896864
# eps is 0.30000000000000004, minp is 9.139999999999997, 0.3596598673352886
# eps is 0.30000000000000004, minp is 9.829999999999997, 0.3596598673352886
# eps is 0.30000000000000004, minp is 10.519999999999996, 0.36059066360604675
# eps is 0.30000000000000004, minp is 11.209999999999996, 0.35462014933522323
# eps is 0.30000000000000004, minp is 11.899999999999995, 0.35462014933522323
# eps is 0.30000000000000004, minp is 12.589999999999995, 0.34198544255573493
# eps is 0.30000000000000004, minp is 13.279999999999994, 0.33838803147703833
# eps is 0.30000000000000004, minp is 13.969999999999994, 0.33838803147703833
# eps is 0.30000000000000004, minp is 14.659999999999993, 0.3372727377752332
# eps is 0.30000000000000004, minp is 15.349999999999993, 0.34355887998920587
# eps is 0.30000000000000004, minp is 16.039999999999992, 0.2859078631004556
# eps is 0.30000000000000004, minp is 16.72999999999999, 0.2859078631004556
# eps is 0.30000000000000004, minp is 17.41999999999999, 0.2849535084908173
# eps is 0.30000000000000004, minp is 18.109999999999992, 0.2820673881890312
# eps is 0.30000000000000004, minp is 18.79999999999999, 0.2820673881890312
# eps is 0.30000000000000004, minp is 19.489999999999988, 0.23940252322891198
# eps is 0.30000000000000004, minp is 20.17999999999999, 0.23426288927178932
# eps is 0.30000000000000004, minp is 20.86999999999999, 0.23426288927178932
# eps is 0.30000000000000004, minp is 21.559999999999988, 0.2338917517216802
# eps is 0.30000000000000004, minp is 22.249999999999986, 0.2300727178344377
# eps is 0.30000000000000004, minp is 22.939999999999987, 0.2300727178344377
# eps is 0.30000000000000004, minp is 23.62999999999999, 0.21940145809749131
# eps is 0.30000000000000004, minp is 24.319999999999986, 0.21342363329467778
# eps is 0.30000000000000004, minp is 25.009999999999984, 0.19686449935951628
# eps is 0.30000000000000004, minp is 25.699999999999985, 0.19686449935951628
# eps is 0.4, minp is 5.0, 0.4531919763890837
# eps is 0.4, minp is 5.6899999999999995, 0.4485337225414618
# eps is 0.4, minp is 6.379999999999999, 0.4485337225414618
# eps is 0.4, minp is 7.0699999999999985, 0.4485337225414618
# eps is 0.4, minp is 7.759999999999998, 0.4485337225414618
# eps is 0.4, minp is 8.449999999999998, 0.4200116539818508
# eps is 0.4, minp is 9.139999999999997, 0.39959879394893216
# eps is 0.4, minp is 9.829999999999997, 0.39959879394893216
# eps is 0.4, minp is 10.519999999999996, 0.3895643889549862
# eps is 0.4, minp is 11.209999999999996, 0.3895643889549862
# eps is 0.4, minp is 11.899999999999995, 0.3895643889549862
# eps is 0.4, minp is 12.589999999999995, 0.3895643889549862
# eps is 0.4, minp is 13.279999999999994, 0.3880513251024352
# eps is 0.4, minp is 13.969999999999994, 0.3880513251024352
# eps is 0.4, minp is 14.659999999999993, 0.3918967769183061
# eps is 0.4, minp is 15.349999999999993, 0.3918967769183061
# eps is 0.4, minp is 16.039999999999992, 0.3918967769183061
# eps is 0.4, minp is 16.72999999999999, 0.3918967769183061
# eps is 0.4, minp is 17.41999999999999, 0.3918967769183061
# eps is 0.4, minp is 18.109999999999992, 0.39496078881176666
# eps is 0.4, minp is 18.79999999999999, 0.39496078881176666
# eps is 0.4, minp is 19.489999999999988, 0.38897834168861006
# eps is 0.4, minp is 20.17999999999999, 0.38956596645139474
# eps is 0.4, minp is 20.86999999999999, 0.38956596645139474
# eps is 0.4, minp is 21.559999999999988, 0.39158405222035353
# eps is 0.4, minp is 22.249999999999986, 0.39158405222035353
# eps is 0.4, minp is 22.939999999999987, 0.39158405222035353
# eps is 0.4, minp is 23.62999999999999, 0.3930822860896008
# eps is 0.4, minp is 24.319999999999986, 0.3930822860896008
# eps is 0.4, minp is 25.009999999999984, 0.3882172435371659
# eps is 0.4, minp is 25.699999999999985, 0.3882172435371659
# eps is 0.5, minp is 5.0, 0.43762353642223145
# eps is 0.5, minp is 5.6899999999999995, 0.43762353642223145
# eps is 0.5, minp is 6.379999999999999, 0.43762353642223145
# eps is 0.5, minp is 7.0699999999999985, 0.43762353642223145
# eps is 0.5, minp is 7.759999999999998, 0.43762353642223145
# eps is 0.5, minp is 8.449999999999998, 0.43762353642223145
# eps is 0.5, minp is 9.139999999999997, 0.43762353642223145
# eps is 0.5, minp is 9.829999999999997, 0.43762353642223145
# eps is 0.5, minp is 10.519999999999996, 0.43762353642223145
# eps is 0.5, minp is 11.209999999999996, 0.42441866437239667
# eps is 0.5, minp is 11.899999999999995, 0.42441866437239667
# eps is 0.5, minp is 12.589999999999995, 0.42441866437239667
# eps is 0.5, minp is 13.279999999999994, 0.42441866437239667
# eps is 0.5, minp is 13.969999999999994, 0.42441866437239667
# eps is 0.5, minp is 14.659999999999993, 0.42441866437239667
# eps is 0.5, minp is 15.349999999999993, 0.43621424543357235
# eps is 0.5, minp is 16.039999999999992, 0.43621424543357235
# eps is 0.5, minp is 16.72999999999999, 0.43621424543357235
# eps is 0.5, minp is 17.41999999999999, 0.43621424543357235
# eps is 0.5, minp is 18.109999999999992, 0.43621424543357235
# eps is 0.5, minp is 18.79999999999999, 0.43621424543357235
# eps is 0.5, minp is 19.489999999999988, 0.43621424543357235
# eps is 0.5, minp is 20.17999999999999, 0.43621424543357235
# eps is 0.5, minp is 20.86999999999999, 0.43621424543357235
# eps is 0.5, minp is 21.559999999999988, 0.4173221126715455
# eps is 0.5, minp is 22.249999999999986, 0.4173221126715455
# eps is 0.5, minp is 22.939999999999987, 0.4173221126715455
# eps is 0.5, minp is 23.62999999999999, 0.4173221126715455
# eps is 0.5, minp is 24.319999999999986, 0.4173221126715455
# eps is 0.5, minp is 25.009999999999984, 0.4173221126715455
# eps is 0.5, minp is 25.699999999999985, 0.4173221126715455
# eps is 0.6, minp is 5.0, 0.4685207355522043
# eps is 0.6, minp is 5.6899999999999995, 0.43277189465756755
# eps is 0.6, minp is 6.379999999999999, 0.43277189465756755
# eps is 0.6, minp is 7.0699999999999985, 0.43277189465756755
# eps is 0.6, minp is 7.759999999999998, 0.43277189465756755
# eps is 0.6, minp is 8.449999999999998, 0.43277189465756755
# eps is 0.6, minp is 9.139999999999997, 0.43277189465756755
# eps is 0.6, minp is 9.829999999999997, 0.43277189465756755
# eps is 0.6, minp is 10.519999999999996, 0.43277189465756755
# eps is 0.6, minp is 11.209999999999996, 0.43277189465756755
# eps is 0.6, minp is 11.899999999999995, 0.43277189465756755
# eps is 0.6, minp is 12.589999999999995, 0.43277189465756755
# eps is 0.6, minp is 13.279999999999994, 0.43277189465756755
# eps is 0.6, minp is 13.969999999999994, 0.43277189465756755
# eps is 0.6, minp is 14.659999999999993, 0.43277189465756755
# eps is 0.6, minp is 15.349999999999993, 0.43277189465756755
# eps is 0.6, minp is 16.039999999999992, 0.43277189465756755
# eps is 0.6, minp is 16.72999999999999, 0.43277189465756755
# eps is 0.6, minp is 17.41999999999999, 0.43277189465756755
# eps is 0.6, minp is 18.109999999999992, 0.43277189465756755
# eps is 0.6, minp is 18.79999999999999, 0.43277189465756755
# eps is 0.6, minp is 19.489999999999988, 0.43277189465756755
# eps is 0.6, minp is 20.17999999999999, 0.43277189465756755
# eps is 0.6, minp is 20.86999999999999, 0.43277189465756755
# eps is 0.6, minp is 21.559999999999988, 0.43277189465756755
# eps is 0.6, minp is 22.249999999999986, 0.43277189465756755
# eps is 0.6, minp is 22.939999999999987, 0.43277189465756755
# eps is 0.6, minp is 23.62999999999999, 0.43277189465756755
# eps is 0.6, minp is 24.319999999999986, 0.43277189465756755
# eps is 0.6, minp is 25.009999999999984, 0.43277189465756755
# eps is 0.6, minp is 25.699999999999985, 0.43277189465756755
# eps is 0.7000000000000001, minp is 5.0, one cluster
# eps is 0.7000000000000001, minp is 5.6899999999999995, 0.4685207355522043
# eps is 0.7000000000000001, minp is 6.379999999999999, 0.4685207355522043
# eps is 0.7000000000000001, minp is 7.0699999999999985, 0.4685207355522043
# eps is 0.7000000000000001, minp is 7.759999999999998, 0.4685207355522043
# eps is 0.7000000000000001, minp is 8.449999999999998, 0.4685207355522043
# eps is 0.7000000000000001, minp is 9.139999999999997, 0.4685207355522043
# eps is 0.7000000000000001, minp is 9.829999999999997, 0.4685207355522043
# eps is 0.7000000000000001, minp is 10.519999999999996, 0.4685207355522043
# eps is 0.7000000000000001, minp is 11.209999999999996, 0.4685207355522043
# eps is 0.7000000000000001, minp is 11.899999999999995, 0.4685207355522043
# eps is 0.7000000000000001, minp is 12.589999999999995, 0.4685207355522043
# eps is 0.7000000000000001, minp is 13.279999999999994, 0.4685207355522043
# eps is 0.7000000000000001, minp is 13.969999999999994, 0.4685207355522043
# eps is 0.7000000000000001, minp is 14.659999999999993, 0.4685207355522043
# eps is 0.7000000000000001, minp is 15.349999999999993, 0.4685207355522043
# eps is 0.7000000000000001, minp is 16.039999999999992, 0.4685207355522043
# eps is 0.7000000000000001, minp is 16.72999999999999, 0.4685207355522043
# eps is 0.7000000000000001, minp is 17.41999999999999, 0.4685207355522043
# eps is 0.7000000000000001, minp is 18.109999999999992, 0.4685207355522043
# eps is 0.7000000000000001, minp is 18.79999999999999, 0.4685207355522043
# eps is 0.7000000000000001, minp is 19.489999999999988, 0.4685207355522043
# eps is 0.7000000000000001, minp is 20.17999999999999, 0.4685207355522043
# eps is 0.7000000000000001, minp is 20.86999999999999, 0.4685207355522043
# eps is 0.7000000000000001, minp is 21.559999999999988, 0.4685207355522043
# eps is 0.7000000000000001, minp is 22.249999999999986, 0.4685207355522043
# eps is 0.7000000000000001, minp is 22.939999999999987, 0.4685207355522043
# eps is 0.7000000000000001, minp is 23.62999999999999, 0.4685207355522043
# eps is 0.7000000000000001, minp is 24.319999999999986, 0.4685207355522043
# eps is 0.7000000000000001, minp is 25.009999999999984, 0.4685207355522043
# eps is 0.7000000000000001, minp is 25.699999999999985, 0.4685207355522043
# eps is 0.8, minp is 5.0, one cluster
# eps is 0.8, minp is 5.6899999999999995, one cluster
# eps is 0.8, minp is 6.379999999999999, one cluster
# eps is 0.8, minp is 7.0699999999999985, one cluster
# eps is 0.8, minp is 7.759999999999998, one cluster
# eps is 0.8, minp is 8.449999999999998, one cluster
# eps is 0.8, minp is 9.139999999999997, one cluster
# eps is 0.8, minp is 9.829999999999997, one cluster
# eps is 0.8, minp is 10.519999999999996, one cluster
# eps is 0.8, minp is 11.209999999999996, one cluster
# eps is 0.8, minp is 11.899999999999995, one cluster
# eps is 0.8, minp is 12.589999999999995, one cluster
# eps is 0.8, minp is 13.279999999999994, one cluster
# eps is 0.8, minp is 13.969999999999994, one cluster
# eps is 0.8, minp is 14.659999999999993, 0.4685207355522043
# eps is 0.8, minp is 15.349999999999993, 0.4685207355522043
# eps is 0.8, minp is 16.039999999999992, 0.4685207355522043
# eps is 0.8, minp is 16.72999999999999, 0.4685207355522043
# eps is 0.8, minp is 17.41999999999999, 0.4685207355522043
# eps is 0.8, minp is 18.109999999999992, 0.4685207355522043
# eps is 0.8, minp is 18.79999999999999, 0.4685207355522043
# eps is 0.8, minp is 19.489999999999988, 0.4685207355522043
# eps is 0.8, minp is 20.17999999999999, 0.4685207355522043
# eps is 0.8, minp is 20.86999999999999, 0.4685207355522043
# eps is 0.8, minp is 21.559999999999988, 0.4685207355522043
# eps is 0.8, minp is 22.249999999999986, 0.4685207355522043
# eps is 0.8, minp is 22.939999999999987, 0.4685207355522043
# eps is 0.8, minp is 23.62999999999999, 0.4685207355522043
# eps is 0.8, minp is 24.319999999999986, 0.4685207355522043
# eps is 0.8, minp is 25.009999999999984, 0.4685207355522043
# eps is 0.8, minp is 25.699999999999985, 0.4685207355522043
# eps is 0.9, minp is 5.0, one cluster
# eps is 0.9, minp is 5.6899999999999995, one cluster
# eps is 0.9, minp is 6.379999999999999, one cluster
# eps is 0.9, minp is 7.0699999999999985, one cluster
# eps is 0.9, minp is 7.759999999999998, one cluster
# eps is 0.9, minp is 8.449999999999998, one cluster
# eps is 0.9, minp is 9.139999999999997, one cluster
# eps is 0.9, minp is 9.829999999999997, one cluster
# eps is 0.9, minp is 10.519999999999996, one cluster
# eps is 0.9, minp is 11.209999999999996, one cluster
# eps is 0.9, minp is 11.899999999999995, one cluster
# eps is 0.9, minp is 12.589999999999995, one cluster
# eps is 0.9, minp is 13.279999999999994, one cluster
# eps is 0.9, minp is 13.969999999999994, one cluster
# eps is 0.9, minp is 14.659999999999993, one cluster
# eps is 0.9, minp is 15.349999999999993, one cluster
# eps is 0.9, minp is 16.039999999999992, one cluster
# eps is 0.9, minp is 16.72999999999999, one cluster
# eps is 0.9, minp is 17.41999999999999, one cluster
# eps is 0.9, minp is 18.109999999999992, one cluster
# eps is 0.9, minp is 18.79999999999999, one cluster
# eps is 0.9, minp is 19.489999999999988, one cluster
# eps is 0.9, minp is 20.17999999999999, one cluster
# eps is 0.9, minp is 20.86999999999999, one cluster
# eps is 0.9, minp is 21.559999999999988, 0.4685207355522043
# eps is 0.9, minp is 22.249999999999986, 0.4685207355522043
# eps is 0.9, minp is 22.939999999999987, 0.4685207355522043
# eps is 0.9, minp is 23.62999999999999, 0.4685207355522043
# eps is 0.9, minp is 24.319999999999986, 0.4685207355522043
# eps is 0.9, minp is 25.009999999999984, 0.4685207355522043
# eps is 0.9, minp is 25.699999999999985, 0.4685207355522043
# eps is 1.0, minp is 5.0, one cluster
# eps is 1.0, minp is 5.6899999999999995, one cluster
# eps is 1.0, minp is 6.379999999999999, one cluster
# eps is 1.0, minp is 7.0699999999999985, one cluster
# eps is 1.0, minp is 7.759999999999998, one cluster
# eps is 1.0, minp is 8.449999999999998, one cluster
# eps is 1.0, minp is 9.139999999999997, one cluster
# eps is 1.0, minp is 9.829999999999997, one cluster
# eps is 1.0, minp is 10.519999999999996, one cluster
# eps is 1.0, minp is 11.209999999999996, one cluster
# eps is 1.0, minp is 11.899999999999995, one cluster
# eps is 1.0, minp is 12.589999999999995, one cluster
# eps is 1.0, minp is 13.279999999999994, one cluster
# eps is 1.0, minp is 13.969999999999994, one cluster
# eps is 1.0, minp is 14.659999999999993, one cluster
# eps is 1.0, minp is 15.349999999999993, one cluster
# eps is 1.0, minp is 16.039999999999992, one cluster
# eps is 1.0, minp is 16.72999999999999, one cluster
# eps is 1.0, minp is 17.41999999999999, one cluster
# eps is 1.0, minp is 18.109999999999992, one cluster
# eps is 1.0, minp is 18.79999999999999, one cluster
# eps is 1.0, minp is 19.489999999999988, one cluster
# eps is 1.0, minp is 20.17999999999999, one cluster
# eps is 1.0, minp is 20.86999999999999, one cluster
# eps is 1.0, minp is 21.559999999999988, one cluster
# eps is 1.0, minp is 22.249999999999986, one cluster
# eps is 1.0, minp is 22.939999999999987, one cluster
# eps is 1.0, minp is 23.62999999999999, one cluster
# eps is 1.0, minp is 24.319999999999986, one cluster
# eps is 1.0, minp is 25.009999999999984, one cluster
# eps is 1.0, minp is 25.699999999999985, one cluster
# eps is 1.1, minp is 5.0, one cluster
# eps is 1.1, minp is 5.6899999999999995, one cluster
# eps is 1.1, minp is 6.379999999999999, one cluster
# eps is 1.1, minp is 7.0699999999999985, one cluster
# eps is 1.1, minp is 7.759999999999998, one cluster
# eps is 1.1, minp is 8.449999999999998, one cluster
# eps is 1.1, minp is 9.139999999999997, one cluster
# eps is 1.1, minp is 9.829999999999997, one cluster
# eps is 1.1, minp is 10.519999999999996, one cluster
# eps is 1.1, minp is 11.209999999999996, one cluster
# eps is 1.1, minp is 11.899999999999995, one cluster
# eps is 1.1, minp is 12.589999999999995, one cluster
# eps is 1.1, minp is 13.279999999999994, one cluster
# eps is 1.1, minp is 13.969999999999994, one cluster
# eps is 1.1, minp is 14.659999999999993, one cluster
# eps is 1.1, minp is 15.349999999999993, one cluster
# eps is 1.1, minp is 16.039999999999992, one cluster
# eps is 1.1, minp is 16.72999999999999, one cluster
# eps is 1.1, minp is 17.41999999999999, one cluster
# eps is 1.1, minp is 18.109999999999992, one cluster
# eps is 1.1, minp is 18.79999999999999, one cluster
# eps is 1.1, minp is 19.489999999999988, one cluster
# eps is 1.1, minp is 20.17999999999999, one cluster
# eps is 1.1, minp is 20.86999999999999, one cluster
# eps is 1.1, minp is 21.559999999999988, one cluster
# eps is 1.1, minp is 22.249999999999986, one cluster
# eps is 1.1, minp is 22.939999999999987, one cluster
# eps is 1.1, minp is 23.62999999999999, one cluster
# eps is 1.1, minp is 24.319999999999986, one cluster
# eps is 1.1, minp is 25.009999999999984, one cluster
# eps is 1.1, minp is 25.699999999999985, one cluster
# eps is 1.2000000000000002, minp is 5.0, one cluster
# eps is 1.2000000000000002, minp is 5.6899999999999995, one cluster
# eps is 1.2000000000000002, minp is 6.379999999999999, one cluster
# eps is 1.2000000000000002, minp is 7.0699999999999985, one cluster
# eps is 1.2000000000000002, minp is 7.759999999999998, one cluster
# eps is 1.2000000000000002, minp is 8.449999999999998, one cluster
# eps is 1.2000000000000002, minp is 9.139999999999997, one cluster
# eps is 1.2000000000000002, minp is 9.829999999999997, one cluster
# eps is 1.2000000000000002, minp is 10.519999999999996, one cluster
# eps is 1.2000000000000002, minp is 11.209999999999996, one cluster
# eps is 1.2000000000000002, minp is 11.899999999999995, one cluster
# eps is 1.2000000000000002, minp is 12.589999999999995, one cluster
# eps is 1.2000000000000002, minp is 13.279999999999994, one cluster
# eps is 1.2000000000000002, minp is 13.969999999999994, one cluster
# eps is 1.2000000000000002, minp is 14.659999999999993, one cluster
# eps is 1.2000000000000002, minp is 15.349999999999993, one cluster
# eps is 1.2000000000000002, minp is 16.039999999999992, one cluster
# eps is 1.2000000000000002, minp is 16.72999999999999, one cluster
# eps is 1.2000000000000002, minp is 17.41999999999999, one cluster
# eps is 1.2000000000000002, minp is 18.109999999999992, one cluster
# eps is 1.2000000000000002, minp is 18.79999999999999, one cluster
# eps is 1.2000000000000002, minp is 19.489999999999988, one cluster
# eps is 1.2000000000000002, minp is 20.17999999999999, one cluster
# eps is 1.2000000000000002, minp is 20.86999999999999, one cluster
# eps is 1.2000000000000002, minp is 21.559999999999988, one cluster
# eps is 1.2000000000000002, minp is 22.249999999999986, one cluster
# eps is 1.2000000000000002, minp is 22.939999999999987, one cluster
# eps is 1.2000000000000002, minp is 23.62999999999999, one cluster
# eps is 1.2000000000000002, minp is 24.319999999999986, one cluster
# eps is 1.2000000000000002, minp is 25.009999999999984, one cluster
# eps is 1.2000000000000002, minp is 25.699999999999985, one cluster
# eps is 1.3000000000000003, minp is 5.0, one cluster
# eps is 1.3000000000000003, minp is 5.6899999999999995, one cluster
# eps is 1.3000000000000003, minp is 6.379999999999999, one cluster
# eps is 1.3000000000000003, minp is 7.0699999999999985, one cluster
# eps is 1.3000000000000003, minp is 7.759999999999998, one cluster
# eps is 1.3000000000000003, minp is 8.449999999999998, one cluster
# eps is 1.3000000000000003, minp is 9.139999999999997, one cluster
# eps is 1.3000000000000003, minp is 9.829999999999997, one cluster
# eps is 1.3000000000000003, minp is 10.519999999999996, one cluster
# eps is 1.3000000000000003, minp is 11.209999999999996, one cluster
# eps is 1.3000000000000003, minp is 11.899999999999995, one cluster
# eps is 1.3000000000000003, minp is 12.589999999999995, one cluster
# eps is 1.3000000000000003, minp is 13.279999999999994, one cluster
# eps is 1.3000000000000003, minp is 13.969999999999994, one cluster
# eps is 1.3000000000000003, minp is 14.659999999999993, one cluster
# eps is 1.3000000000000003, minp is 15.349999999999993, one cluster
# eps is 1.3000000000000003, minp is 16.039999999999992, one cluster
# eps is 1.3000000000000003, minp is 16.72999999999999, one cluster
# eps is 1.3000000000000003, minp is 17.41999999999999, one cluster
# eps is 1.3000000000000003, minp is 18.109999999999992, one cluster
# eps is 1.3000000000000003, minp is 18.79999999999999, one cluster
# eps is 1.3000000000000003, minp is 19.489999999999988, one cluster
# eps is 1.3000000000000003, minp is 20.17999999999999, one cluster
# eps is 1.3000000000000003, minp is 20.86999999999999, one cluster
# eps is 1.3000000000000003, minp is 21.559999999999988, one cluster
# eps is 1.3000000000000003, minp is 22.249999999999986, one cluster
# eps is 1.3000000000000003, minp is 22.939999999999987, one cluster
# eps is 1.3000000000000003, minp is 23.62999999999999, one cluster
# eps is 1.3000000000000003, minp is 24.319999999999986, one cluster
# eps is 1.3000000000000003, minp is 25.009999999999984, one cluster
# eps is 1.3000000000000003, minp is 25.699999999999985, one cluster
# eps is 1.4000000000000001, minp is 5.0, one cluster
# eps is 1.4000000000000001, minp is 5.6899999999999995, one cluster
# eps is 1.4000000000000001, minp is 6.379999999999999, one cluster
# eps is 1.4000000000000001, minp is 7.0699999999999985, one cluster
# eps is 1.4000000000000001, minp is 7.759999999999998, one cluster
# eps is 1.4000000000000001, minp is 8.449999999999998, one cluster
# eps is 1.4000000000000001, minp is 9.139999999999997, one cluster
# eps is 1.4000000000000001, minp is 9.829999999999997, one cluster
# eps is 1.4000000000000001, minp is 10.519999999999996, one cluster
# eps is 1.4000000000000001, minp is 11.209999999999996, one cluster
# eps is 1.4000000000000001, minp is 11.899999999999995, one cluster
# eps is 1.4000000000000001, minp is 12.589999999999995, one cluster
# eps is 1.4000000000000001, minp is 13.279999999999994, one cluster
# eps is 1.4000000000000001, minp is 13.969999999999994, one cluster
# eps is 1.4000000000000001, minp is 14.659999999999993, one cluster
# eps is 1.4000000000000001, minp is 15.349999999999993, one cluster
# eps is 1.4000000000000001, minp is 16.039999999999992, one cluster
# eps is 1.4000000000000001, minp is 16.72999999999999, one cluster
# eps is 1.4000000000000001, minp is 17.41999999999999, one cluster
# eps is 1.4000000000000001, minp is 18.109999999999992, one cluster
# eps is 1.4000000000000001, minp is 18.79999999999999, one cluster
# eps is 1.4000000000000001, minp is 19.489999999999988, one cluster
# eps is 1.4000000000000001, minp is 20.17999999999999, one cluster
# eps is 1.4000000000000001, minp is 20.86999999999999, one cluster
# eps is 1.4000000000000001, minp is 21.559999999999988, one cluster
# eps is 1.4000000000000001, minp is 22.249999999999986, one cluster
# eps is 1.4000000000000001, minp is 22.939999999999987, one cluster
# eps is 1.4000000000000001, minp is 23.62999999999999, one cluster
# eps is 1.4000000000000001, minp is 24.319999999999986, one cluster
# eps is 1.4000000000000001, minp is 25.009999999999984, one cluster
# eps is 1.4000000000000001, minp is 25.699999999999985, one cluster
# eps is 1.5000000000000002, minp is 5.0, one cluster
# eps is 1.5000000000000002, minp is 5.6899999999999995, one cluster
# eps is 1.5000000000000002, minp is 6.379999999999999, one cluster
# eps is 1.5000000000000002, minp is 7.0699999999999985, one cluster
# eps is 1.5000000000000002, minp is 7.759999999999998, one cluster
# eps is 1.5000000000000002, minp is 8.449999999999998, one cluster
# eps is 1.5000000000000002, minp is 9.139999999999997, one cluster
# eps is 1.5000000000000002, minp is 9.829999999999997, one cluster
# eps is 1.5000000000000002, minp is 10.519999999999996, one cluster
# eps is 1.5000000000000002, minp is 11.209999999999996, one cluster
# eps is 1.5000000000000002, minp is 11.899999999999995, one cluster
# eps is 1.5000000000000002, minp is 12.589999999999995, one cluster
# eps is 1.5000000000000002, minp is 13.279999999999994, one cluster
# eps is 1.5000000000000002, minp is 13.969999999999994, one cluster
# eps is 1.5000000000000002, minp is 14.659999999999993, one cluster
# eps is 1.5000000000000002, minp is 15.349999999999993, one cluster
# eps is 1.5000000000000002, minp is 16.039999999999992, one cluster
# eps is 1.5000000000000002, minp is 16.72999999999999, one cluster
# eps is 1.5000000000000002, minp is 17.41999999999999, one cluster
# eps is 1.5000000000000002, minp is 18.109999999999992, one cluster
# eps is 1.5000000000000002, minp is 18.79999999999999, one cluster
# eps is 1.5000000000000002, minp is 19.489999999999988, one cluster
# eps is 1.5000000000000002, minp is 20.17999999999999, one cluster
# eps is 1.5000000000000002, minp is 20.86999999999999, one cluster
# eps is 1.5000000000000002, minp is 21.559999999999988, one cluster
# eps is 1.5000000000000002, minp is 22.249999999999986, one cluster
# eps is 1.5000000000000002, minp is 22.939999999999987, one cluster
# eps is 1.5000000000000002, minp is 23.62999999999999, one cluster
# eps is 1.5000000000000002, minp is 24.319999999999986, one cluster
# eps is 1.5000000000000002, minp is 25.009999999999984, one cluster
# eps is 1.5000000000000002, minp is 25.699999999999985, one cluster
# eps is 1.6, minp is 5.0, one cluster
# eps is 1.6, minp is 5.6899999999999995, one cluster
# eps is 1.6, minp is 6.379999999999999, one cluster
# eps is 1.6, minp is 7.0699999999999985, one cluster
# eps is 1.6, minp is 7.759999999999998, one cluster
# eps is 1.6, minp is 8.449999999999998, one cluster
# eps is 1.6, minp is 9.139999999999997, one cluster
# eps is 1.6, minp is 9.829999999999997, one cluster
# eps is 1.6, minp is 10.519999999999996, one cluster
# eps is 1.6, minp is 11.209999999999996, one cluster
# eps is 1.6, minp is 11.899999999999995, one cluster
# eps is 1.6, minp is 12.589999999999995, one cluster
# eps is 1.6, minp is 13.279999999999994, one cluster
# eps is 1.6, minp is 13.969999999999994, one cluster
# eps is 1.6, minp is 14.659999999999993, one cluster
# eps is 1.6, minp is 15.349999999999993, one cluster
# eps is 1.6, minp is 16.039999999999992, one cluster
# eps is 1.6, minp is 16.72999999999999, one cluster
# eps is 1.6, minp is 17.41999999999999, one cluster
# eps is 1.6, minp is 18.109999999999992, one cluster
# eps is 1.6, minp is 18.79999999999999, one cluster
# eps is 1.6, minp is 19.489999999999988, one cluster
# eps is 1.6, minp is 20.17999999999999, one cluster
# eps is 1.6, minp is 20.86999999999999, one cluster
# eps is 1.6, minp is 21.559999999999988, one cluster
# eps is 1.6, minp is 22.249999999999986, one cluster
# eps is 1.6, minp is 22.939999999999987, one cluster
# eps is 1.6, minp is 23.62999999999999, one cluster
# eps is 1.6, minp is 24.319999999999986, one cluster
# eps is 1.6, minp is 25.009999999999984, one cluster
# eps is 1.6, minp is 25.699999999999985, one cluster
# eps is 1.7000000000000002, minp is 5.0, one cluster
# eps is 1.7000000000000002, minp is 5.6899999999999995, one cluster
# eps is 1.7000000000000002, minp is 6.379999999999999, one cluster
# eps is 1.7000000000000002, minp is 7.0699999999999985, one cluster
# eps is 1.7000000000000002, minp is 7.759999999999998, one cluster
# eps is 1.7000000000000002, minp is 8.449999999999998, one cluster
# eps is 1.7000000000000002, minp is 9.139999999999997, one cluster
# eps is 1.7000000000000002, minp is 9.829999999999997, one cluster
# eps is 1.7000000000000002, minp is 10.519999999999996, one cluster
# eps is 1.7000000000000002, minp is 11.209999999999996, one cluster
# eps is 1.7000000000000002, minp is 11.899999999999995, one cluster
# eps is 1.7000000000000002, minp is 12.589999999999995, one cluster
# eps is 1.7000000000000002, minp is 13.279999999999994, one cluster
# eps is 1.7000000000000002, minp is 13.969999999999994, one cluster
# eps is 1.7000000000000002, minp is 14.659999999999993, one cluster
# eps is 1.7000000000000002, minp is 15.349999999999993, one cluster
# eps is 1.7000000000000002, minp is 16.039999999999992, one cluster
# eps is 1.7000000000000002, minp is 16.72999999999999, one cluster
# eps is 1.7000000000000002, minp is 17.41999999999999, one cluster
# eps is 1.7000000000000002, minp is 18.109999999999992, one cluster
# eps is 1.7000000000000002, minp is 18.79999999999999, one cluster
# eps is 1.7000000000000002, minp is 19.489999999999988, one cluster
# eps is 1.7000000000000002, minp is 20.17999999999999, one cluster
# eps is 1.7000000000000002, minp is 20.86999999999999, one cluster
# eps is 1.7000000000000002, minp is 21.559999999999988, one cluster
# eps is 1.7000000000000002, minp is 22.249999999999986, one cluster
# eps is 1.7000000000000002, minp is 22.939999999999987, one cluster
# eps is 1.7000000000000002, minp is 23.62999999999999, one cluster
# eps is 1.7000000000000002, minp is 24.319999999999986, one cluster
# eps is 1.7000000000000002, minp is 25.009999999999984, one cluster
# eps is 1.7000000000000002, minp is 25.699999999999985, one cluster
# eps is 1.8000000000000003, minp is 5.0, one cluster
# eps is 1.8000000000000003, minp is 5.6899999999999995, one cluster
# eps is 1.8000000000000003, minp is 6.379999999999999, one cluster
# eps is 1.8000000000000003, minp is 7.0699999999999985, one cluster
# eps is 1.8000000000000003, minp is 7.759999999999998, one cluster
# eps is 1.8000000000000003, minp is 8.449999999999998, one cluster
# eps is 1.8000000000000003, minp is 9.139999999999997, one cluster
# eps is 1.8000000000000003, minp is 9.829999999999997, one cluster
# eps is 1.8000000000000003, minp is 10.519999999999996, one cluster
# eps is 1.8000000000000003, minp is 11.209999999999996, one cluster
# eps is 1.8000000000000003, minp is 11.899999999999995, one cluster
# eps is 1.8000000000000003, minp is 12.589999999999995, one cluster
# eps is 1.8000000000000003, minp is 13.279999999999994, one cluster
# eps is 1.8000000000000003, minp is 13.969999999999994, one cluster
# eps is 1.8000000000000003, minp is 14.659999999999993, one cluster
# eps is 1.8000000000000003, minp is 15.349999999999993, one cluster
# eps is 1.8000000000000003, minp is 16.039999999999992, one cluster
# eps is 1.8000000000000003, minp is 16.72999999999999, one cluster
# eps is 1.8000000000000003, minp is 17.41999999999999, one cluster
# eps is 1.8000000000000003, minp is 18.109999999999992, one cluster
# eps is 1.8000000000000003, minp is 18.79999999999999, one cluster
# eps is 1.8000000000000003, minp is 19.489999999999988, one cluster
# eps is 1.8000000000000003, minp is 20.17999999999999, one cluster
# eps is 1.8000000000000003, minp is 20.86999999999999, one cluster
# eps is 1.8000000000000003, minp is 21.559999999999988, one cluster
# eps is 1.8000000000000003, minp is 22.249999999999986, one cluster
# eps is 1.8000000000000003, minp is 22.939999999999987, one cluster
# eps is 1.8000000000000003, minp is 23.62999999999999, one cluster
# eps is 1.8000000000000003, minp is 24.319999999999986, one cluster
# eps is 1.8000000000000003, minp is 25.009999999999984, one cluster
# eps is 1.8000000000000003, minp is 25.699999999999985, one cluster
# eps is 1.9000000000000001, minp is 5.0, one cluster
# eps is 1.9000000000000001, minp is 5.6899999999999995, one cluster
# eps is 1.9000000000000001, minp is 6.379999999999999, one cluster
# eps is 1.9000000000000001, minp is 7.0699999999999985, one cluster
# eps is 1.9000000000000001, minp is 7.759999999999998, one cluster
# eps is 1.9000000000000001, minp is 8.449999999999998, one cluster
# eps is 1.9000000000000001, minp is 9.139999999999997, one cluster
# eps is 1.9000000000000001, minp is 9.829999999999997, one cluster
# eps is 1.9000000000000001, minp is 10.519999999999996, one cluster
# eps is 1.9000000000000001, minp is 11.209999999999996, one cluster
# eps is 1.9000000000000001, minp is 11.899999999999995, one cluster
# eps is 1.9000000000000001, minp is 12.589999999999995, one cluster
# eps is 1.9000000000000001, minp is 13.279999999999994, one cluster
# eps is 1.9000000000000001, minp is 13.969999999999994, one cluster
# eps is 1.9000000000000001, minp is 14.659999999999993, one cluster
# eps is 1.9000000000000001, minp is 15.349999999999993, one cluster
# eps is 1.9000000000000001, minp is 16.039999999999992, one cluster
# eps is 1.9000000000000001, minp is 16.72999999999999, one cluster
# eps is 1.9000000000000001, minp is 17.41999999999999, one cluster
# eps is 1.9000000000000001, minp is 18.109999999999992, one cluster
# eps is 1.9000000000000001, minp is 18.79999999999999, one cluster
# eps is 1.9000000000000001, minp is 19.489999999999988, one cluster
# eps is 1.9000000000000001, minp is 20.17999999999999, one cluster
# eps is 1.9000000000000001, minp is 20.86999999999999, one cluster
# eps is 1.9000000000000001, minp is 21.559999999999988, one cluster
# eps is 1.9000000000000001, minp is 22.249999999999986, one cluster
# eps is 1.9000000000000001, minp is 22.939999999999987, one cluster
# eps is 1.9000000000000001, minp is 23.62999999999999, one cluster
# eps is 1.9000000000000001, minp is 24.319999999999986, one cluster
# eps is 1.9000000000000001, minp is 25.009999999999984, one cluster
# eps is 1.9000000000000001, minp is 25.699999999999985, one cluster
# eps is 2.0, minp is 5.0, one cluster
# eps is 2.0, minp is 5.6899999999999995, one cluster
# eps is 2.0, minp is 6.379999999999999, one cluster
# eps is 2.0, minp is 7.0699999999999985, one cluster
# eps is 2.0, minp is 7.759999999999998, one cluster
# eps is 2.0, minp is 8.449999999999998, one cluster
# eps is 2.0, minp is 9.139999999999997, one cluster
# eps is 2.0, minp is 9.829999999999997, one cluster
# eps is 2.0, minp is 10.519999999999996, one cluster
# eps is 2.0, minp is 11.209999999999996, one cluster
# eps is 2.0, minp is 11.899999999999995, one cluster
# eps is 2.0, minp is 12.589999999999995, one cluster
# eps is 2.0, minp is 13.279999999999994, one cluster
# eps is 2.0, minp is 13.969999999999994, one cluster
# eps is 2.0, minp is 14.659999999999993, one cluster
# eps is 2.0, minp is 15.349999999999993, one cluster
# eps is 2.0, minp is 16.039999999999992, one cluster
# eps is 2.0, minp is 16.72999999999999, one cluster
# eps is 2.0, minp is 17.41999999999999, one cluster
# eps is 2.0, minp is 18.109999999999992, one cluster
# eps is 2.0, minp is 18.79999999999999, one cluster
# eps is 2.0, minp is 19.489999999999988, one cluster
# eps is 2.0, minp is 20.17999999999999, one cluster
# eps is 2.0, minp is 20.86999999999999, one cluster
# eps is 2.0, minp is 21.559999999999988, one cluster
# eps is 2.0, minp is 22.249999999999986, one cluster
# eps is 2.0, minp is 22.939999999999987, one cluster
# eps is 2.0, minp is 23.62999999999999, one cluster
# eps is 2.0, minp is 24.319999999999986, one cluster
# eps is 2.0, minp is 25.009999999999984, one cluster
# eps is 2.0, minp is 25.699999999999985, one cluster
# eps is 2.1, minp is 5.0, one cluster
# eps is 2.1, minp is 5.6899999999999995, one cluster
# eps is 2.1, minp is 6.379999999999999, one cluster
# eps is 2.1, minp is 7.0699999999999985, one cluster
# eps is 2.1, minp is 7.759999999999998, one cluster
# eps is 2.1, minp is 8.449999999999998, one cluster
# eps is 2.1, minp is 9.139999999999997, one cluster
# eps is 2.1, minp is 9.829999999999997, one cluster
# eps is 2.1, minp is 10.519999999999996, one cluster
# eps is 2.1, minp is 11.209999999999996, one cluster
# eps is 2.1, minp is 11.899999999999995, one cluster
# eps is 2.1, minp is 12.589999999999995, one cluster
# eps is 2.1, minp is 13.279999999999994, one cluster
# eps is 2.1, minp is 13.969999999999994, one cluster
# eps is 2.1, minp is 14.659999999999993, one cluster
# eps is 2.1, minp is 15.349999999999993, one cluster
# eps is 2.1, minp is 16.039999999999992, one cluster
# eps is 2.1, minp is 16.72999999999999, one cluster
# eps is 2.1, minp is 17.41999999999999, one cluster
# eps is 2.1, minp is 18.109999999999992, one cluster
# eps is 2.1, minp is 18.79999999999999, one cluster
# eps is 2.1, minp is 19.489999999999988, one cluster
# eps is 2.1, minp is 20.17999999999999, one cluster
# eps is 2.1, minp is 20.86999999999999, one cluster
# eps is 2.1, minp is 21.559999999999988, one cluster
# eps is 2.1, minp is 22.249999999999986, one cluster
# eps is 2.1, minp is 22.939999999999987, one cluster
# eps is 2.1, minp is 23.62999999999999, one cluster
# eps is 2.1, minp is 24.319999999999986, one cluster
# eps is 2.1, minp is 25.009999999999984, one cluster
# eps is 2.1, minp is 25.699999999999985, one cluster
# eps is 2.2, minp is 5.0, one cluster
# eps is 2.2, minp is 5.6899999999999995, one cluster
# eps is 2.2, minp is 6.379999999999999, one cluster
# eps is 2.2, minp is 7.0699999999999985, one cluster
# eps is 2.2, minp is 7.759999999999998, one cluster
# eps is 2.2, minp is 8.449999999999998, one cluster
# eps is 2.2, minp is 9.139999999999997, one cluster
# eps is 2.2, minp is 9.829999999999997, one cluster
# eps is 2.2, minp is 10.519999999999996, one cluster
# eps is 2.2, minp is 11.209999999999996, one cluster
# eps is 2.2, minp is 11.899999999999995, one cluster
# eps is 2.2, minp is 12.589999999999995, one cluster
# eps is 2.2, minp is 13.279999999999994, one cluster
# eps is 2.2, minp is 13.969999999999994, one cluster
# eps is 2.2, minp is 14.659999999999993, one cluster
# eps is 2.2, minp is 15.349999999999993, one cluster
# eps is 2.2, minp is 16.039999999999992, one cluster
# eps is 2.2, minp is 16.72999999999999, one cluster
# eps is 2.2, minp is 17.41999999999999, one cluster
# eps is 2.2, minp is 18.109999999999992, one cluster
# eps is 2.2, minp is 18.79999999999999, one cluster
# eps is 2.2, minp is 19.489999999999988, one cluster
# eps is 2.2, minp is 20.17999999999999, one cluster
# eps is 2.2, minp is 20.86999999999999, one cluster
# eps is 2.2, minp is 21.559999999999988, one cluster
# eps is 2.2, minp is 22.249999999999986, one cluster
# eps is 2.2, minp is 22.939999999999987, one cluster
# eps is 2.2, minp is 23.62999999999999, one cluster
# eps is 2.2, minp is 24.319999999999986, one cluster
# eps is 2.2, minp is 25.009999999999984, one cluster
# eps is 2.2, minp is 25.699999999999985, one cluster
# eps is 2.3000000000000003, minp is 5.0, one cluster
# eps is 2.3000000000000003, minp is 5.6899999999999995, one cluster
# eps is 2.3000000000000003, minp is 6.379999999999999, one cluster
# eps is 2.3000000000000003, minp is 7.0699999999999985, one cluster
# eps is 2.3000000000000003, minp is 7.759999999999998, one cluster
# eps is 2.3000000000000003, minp is 8.449999999999998, one cluster
# eps is 2.3000000000000003, minp is 9.139999999999997, one cluster
# eps is 2.3000000000000003, minp is 9.829999999999997, one cluster
# eps is 2.3000000000000003, minp is 10.519999999999996, one cluster
# eps is 2.3000000000000003, minp is 11.209999999999996, one cluster
# eps is 2.3000000000000003, minp is 11.899999999999995, one cluster
# eps is 2.3000000000000003, minp is 12.589999999999995, one cluster
# eps is 2.3000000000000003, minp is 13.279999999999994, one cluster
# eps is 2.3000000000000003, minp is 13.969999999999994, one cluster
# eps is 2.3000000000000003, minp is 14.659999999999993, one cluster
# eps is 2.3000000000000003, minp is 15.349999999999993, one cluster
# eps is 2.3000000000000003, minp is 16.039999999999992, one cluster
# eps is 2.3000000000000003, minp is 16.72999999999999, one cluster
# eps is 2.3000000000000003, minp is 17.41999999999999, one cluster
# eps is 2.3000000000000003, minp is 18.109999999999992, one cluster
# eps is 2.3000000000000003, minp is 18.79999999999999, one cluster
# eps is 2.3000000000000003, minp is 19.489999999999988, one cluster
# eps is 2.3000000000000003, minp is 20.17999999999999, one cluster
# eps is 2.3000000000000003, minp is 20.86999999999999, one cluster
# eps is 2.3000000000000003, minp is 21.559999999999988, one cluster
# eps is 2.3000000000000003, minp is 22.249999999999986, one cluster
# eps is 2.3000000000000003, minp is 22.939999999999987, one cluster
# eps is 2.3000000000000003, minp is 23.62999999999999, one cluster
# eps is 2.3000000000000003, minp is 24.319999999999986, one cluster
# eps is 2.3000000000000003, minp is 25.009999999999984, one cluster
# eps is 2.3000000000000003, minp is 25.699999999999985, one cluster
# eps is 2.4000000000000004, minp is 5.0, one cluster
# eps is 2.4000000000000004, minp is 5.6899999999999995, one cluster
# eps is 2.4000000000000004, minp is 6.379999999999999, one cluster
# eps is 2.4000000000000004, minp is 7.0699999999999985, one cluster
# eps is 2.4000000000000004, minp is 7.759999999999998, one cluster
# eps is 2.4000000000000004, minp is 8.449999999999998, one cluster
# eps is 2.4000000000000004, minp is 9.139999999999997, one cluster
# eps is 2.4000000000000004, minp is 9.829999999999997, one cluster
# eps is 2.4000000000000004, minp is 10.519999999999996, one cluster
# eps is 2.4000000000000004, minp is 11.209999999999996, one cluster
# eps is 2.4000000000000004, minp is 11.899999999999995, one cluster
# eps is 2.4000000000000004, minp is 12.589999999999995, one cluster
# eps is 2.4000000000000004, minp is 13.279999999999994, one cluster
# eps is 2.4000000000000004, minp is 13.969999999999994, one cluster
# eps is 2.4000000000000004, minp is 14.659999999999993, one cluster
# eps is 2.4000000000000004, minp is 15.349999999999993, one cluster
# eps is 2.4000000000000004, minp is 16.039999999999992, one cluster
# eps is 2.4000000000000004, minp is 16.72999999999999, one cluster
# eps is 2.4000000000000004, minp is 17.41999999999999, one cluster
# eps is 2.4000000000000004, minp is 18.109999999999992, one cluster
# eps is 2.4000000000000004, minp is 18.79999999999999, one cluster
# eps is 2.4000000000000004, minp is 19.489999999999988, one cluster
# eps is 2.4000000000000004, minp is 20.17999999999999, one cluster
# eps is 2.4000000000000004, minp is 20.86999999999999, one cluster
# eps is 2.4000000000000004, minp is 21.559999999999988, one cluster
# eps is 2.4000000000000004, minp is 22.249999999999986, one cluster
# eps is 2.4000000000000004, minp is 22.939999999999987, one cluster
# eps is 2.4000000000000004, minp is 23.62999999999999, one cluster
# eps is 2.4000000000000004, minp is 24.319999999999986, one cluster
# eps is 2.4000000000000004, minp is 25.009999999999984, one cluster
# eps is 2.4000000000000004, minp is 25.699999999999985, one cluster
# eps is 2.5000000000000004, minp is 5.0, one cluster
# eps is 2.5000000000000004, minp is 5.6899999999999995, one cluster
# eps is 2.5000000000000004, minp is 6.379999999999999, one cluster
# eps is 2.5000000000000004, minp is 7.0699999999999985, one cluster
# eps is 2.5000000000000004, minp is 7.759999999999998, one cluster
# eps is 2.5000000000000004, minp is 8.449999999999998, one cluster
# eps is 2.5000000000000004, minp is 9.139999999999997, one cluster
# eps is 2.5000000000000004, minp is 9.829999999999997, one cluster
# eps is 2.5000000000000004, minp is 10.519999999999996, one cluster
# eps is 2.5000000000000004, minp is 11.209999999999996, one cluster
# eps is 2.5000000000000004, minp is 11.899999999999995, one cluster
# eps is 2.5000000000000004, minp is 12.589999999999995, one cluster
# eps is 2.5000000000000004, minp is 13.279999999999994, one cluster
# eps is 2.5000000000000004, minp is 13.969999999999994, one cluster
# eps is 2.5000000000000004, minp is 14.659999999999993, one cluster
# eps is 2.5000000000000004, minp is 15.349999999999993, one cluster
# eps is 2.5000000000000004, minp is 16.039999999999992, one cluster
# eps is 2.5000000000000004, minp is 16.72999999999999, one cluster
# eps is 2.5000000000000004, minp is 17.41999999999999, one cluster
# eps is 2.5000000000000004, minp is 18.109999999999992, one cluster
# eps is 2.5000000000000004, minp is 18.79999999999999, one cluster
# eps is 2.5000000000000004, minp is 19.489999999999988, one cluster
# eps is 2.5000000000000004, minp is 20.17999999999999, one cluster
# eps is 2.5000000000000004, minp is 20.86999999999999, one cluster
# eps is 2.5000000000000004, minp is 21.559999999999988, one cluster
# eps is 2.5000000000000004, minp is 22.249999999999986, one cluster
# eps is 2.5000000000000004, minp is 22.939999999999987, one cluster
# eps is 2.5000000000000004, minp is 23.62999999999999, one cluster
# eps is 2.5000000000000004, minp is 24.319999999999986, one cluster
# eps is 2.5000000000000004, minp is 25.009999999999984, one cluster
# eps is 2.5000000000000004, minp is 25.699999999999985, one cluster
# eps is 2.6, minp is 5.0, one cluster
# eps is 2.6, minp is 5.6899999999999995, one cluster
# eps is 2.6, minp is 6.379999999999999, one cluster
# eps is 2.6, minp is 7.0699999999999985, one cluster
# eps is 2.6, minp is 7.759999999999998, one cluster
# eps is 2.6, minp is 8.449999999999998, one cluster
# eps is 2.6, minp is 9.139999999999997, one cluster
# eps is 2.6, minp is 9.829999999999997, one cluster
# eps is 2.6, minp is 10.519999999999996, one cluster
# eps is 2.6, minp is 11.209999999999996, one cluster
# eps is 2.6, minp is 11.899999999999995, one cluster
# eps is 2.6, minp is 12.589999999999995, one cluster
# eps is 2.6, minp is 13.279999999999994, one cluster
# eps is 2.6, minp is 13.969999999999994, one cluster
# eps is 2.6, minp is 14.659999999999993, one cluster
# eps is 2.6, minp is 15.349999999999993, one cluster
# eps is 2.6, minp is 16.039999999999992, one cluster
# eps is 2.6, minp is 16.72999999999999, one cluster
# eps is 2.6, minp is 17.41999999999999, one cluster
# eps is 2.6, minp is 18.109999999999992, one cluster
# eps is 2.6, minp is 18.79999999999999, one cluster
# eps is 2.6, minp is 19.489999999999988, one cluster
# eps is 2.6, minp is 20.17999999999999, one cluster
# eps is 2.6, minp is 20.86999999999999, one cluster
# eps is 2.6, minp is 21.559999999999988, one cluster
# eps is 2.6, minp is 22.249999999999986, one cluster
# eps is 2.6, minp is 22.939999999999987, one cluster
# eps is 2.6, minp is 23.62999999999999, one cluster
# eps is 2.6, minp is 24.319999999999986, one cluster
# eps is 2.6, minp is 25.009999999999984, one cluster
# eps is 2.6, minp is 25.699999999999985, one cluster
# eps is 2.7, minp is 5.0, one cluster
# eps is 2.7, minp is 5.6899999999999995, one cluster
# eps is 2.7, minp is 6.379999999999999, one cluster
# eps is 2.7, minp is 7.0699999999999985, one cluster
# eps is 2.7, minp is 7.759999999999998, one cluster
# eps is 2.7, minp is 8.449999999999998, one cluster
# eps is 2.7, minp is 9.139999999999997, one cluster
# eps is 2.7, minp is 9.829999999999997, one cluster
# eps is 2.7, minp is 10.519999999999996, one cluster
# eps is 2.7, minp is 11.209999999999996, one cluster
# eps is 2.7, minp is 11.899999999999995, one cluster
# eps is 2.7, minp is 12.589999999999995, one cluster
# eps is 2.7, minp is 13.279999999999994, one cluster
# eps is 2.7, minp is 13.969999999999994, one cluster
# eps is 2.7, minp is 14.659999999999993, one cluster
# eps is 2.7, minp is 15.349999999999993, one cluster
# eps is 2.7, minp is 16.039999999999992, one cluster
# eps is 2.7, minp is 16.72999999999999, one cluster
# eps is 2.7, minp is 17.41999999999999, one cluster
# eps is 2.7, minp is 18.109999999999992, one cluster
# eps is 2.7, minp is 18.79999999999999, one cluster
# eps is 2.7, minp is 19.489999999999988, one cluster
# eps is 2.7, minp is 20.17999999999999, one cluster
# eps is 2.7, minp is 20.86999999999999, one cluster
# eps is 2.7, minp is 21.559999999999988, one cluster
# eps is 2.7, minp is 22.249999999999986, one cluster
# eps is 2.7, minp is 22.939999999999987, one cluster
# eps is 2.7, minp is 23.62999999999999, one cluster
# eps is 2.7, minp is 24.319999999999986, one cluster
# eps is 2.7, minp is 25.009999999999984, one cluster
# eps is 2.7, minp is 25.699999999999985, one cluster
# eps is 2.8000000000000003, minp is 5.0, one cluster
# eps is 2.8000000000000003, minp is 5.6899999999999995, one cluster
# eps is 2.8000000000000003, minp is 6.379999999999999, one cluster
# eps is 2.8000000000000003, minp is 7.0699999999999985, one cluster
# eps is 2.8000000000000003, minp is 7.759999999999998, one cluster
# eps is 2.8000000000000003, minp is 8.449999999999998, one cluster
# eps is 2.8000000000000003, minp is 9.139999999999997, one cluster
# eps is 2.8000000000000003, minp is 9.829999999999997, one cluster
# eps is 2.8000000000000003, minp is 10.519999999999996, one cluster
# eps is 2.8000000000000003, minp is 11.209999999999996, one cluster
# eps is 2.8000000000000003, minp is 11.899999999999995, one cluster
# eps is 2.8000000000000003, minp is 12.589999999999995, one cluster
# eps is 2.8000000000000003, minp is 13.279999999999994, one cluster
# eps is 2.8000000000000003, minp is 13.969999999999994, one cluster
# eps is 2.8000000000000003, minp is 14.659999999999993, one cluster
# eps is 2.8000000000000003, minp is 15.349999999999993, one cluster
# eps is 2.8000000000000003, minp is 16.039999999999992, one cluster
# eps is 2.8000000000000003, minp is 16.72999999999999, one cluster
# eps is 2.8000000000000003, minp is 17.41999999999999, one cluster
# eps is 2.8000000000000003, minp is 18.109999999999992, one cluster
# eps is 2.8000000000000003, minp is 18.79999999999999, one cluster
# eps is 2.8000000000000003, minp is 19.489999999999988, one cluster
# eps is 2.8000000000000003, minp is 20.17999999999999, one cluster
# eps is 2.8000000000000003, minp is 20.86999999999999, one cluster
# eps is 2.8000000000000003, minp is 21.559999999999988, one cluster
# eps is 2.8000000000000003, minp is 22.249999999999986, one cluster
# eps is 2.8000000000000003, minp is 22.939999999999987, one cluster
# eps is 2.8000000000000003, minp is 23.62999999999999, one cluster
# eps is 2.8000000000000003, minp is 24.319999999999986, one cluster
# eps is 2.8000000000000003, minp is 25.009999999999984, one cluster
# eps is 2.8000000000000003, minp is 25.699999999999985, one cluster
# eps is 2.9000000000000004, minp is 5.0, one cluster
# eps is 2.9000000000000004, minp is 5.6899999999999995, one cluster
# eps is 2.9000000000000004, minp is 6.379999999999999, one cluster
# eps is 2.9000000000000004, minp is 7.0699999999999985, one cluster
# eps is 2.9000000000000004, minp is 7.759999999999998, one cluster
# eps is 2.9000000000000004, minp is 8.449999999999998, one cluster
# eps is 2.9000000000000004, minp is 9.139999999999997, one cluster
# eps is 2.9000000000000004, minp is 9.829999999999997, one cluster
# eps is 2.9000000000000004, minp is 10.519999999999996, one cluster
# eps is 2.9000000000000004, minp is 11.209999999999996, one cluster
# eps is 2.9000000000000004, minp is 11.899999999999995, one cluster
# eps is 2.9000000000000004, minp is 12.589999999999995, one cluster
# eps is 2.9000000000000004, minp is 13.279999999999994, one cluster
# eps is 2.9000000000000004, minp is 13.969999999999994, one cluster
# eps is 2.9000000000000004, minp is 14.659999999999993, one cluster
# eps is 2.9000000000000004, minp is 15.349999999999993, one cluster
# eps is 2.9000000000000004, minp is 16.039999999999992, one cluster
# eps is 2.9000000000000004, minp is 16.72999999999999, one cluster
# eps is 2.9000000000000004, minp is 17.41999999999999, one cluster
# eps is 2.9000000000000004, minp is 18.109999999999992, one cluster
# eps is 2.9000000000000004, minp is 18.79999999999999, one cluster
# eps is 2.9000000000000004, minp is 19.489999999999988, one cluster
# eps is 2.9000000000000004, minp is 20.17999999999999, one cluster
# eps is 2.9000000000000004, minp is 20.86999999999999, one cluster
# eps is 2.9000000000000004, minp is 21.559999999999988, one cluster
# eps is 2.9000000000000004, minp is 22.249999999999986, one cluster
# eps is 2.9000000000000004, minp is 22.939999999999987, one cluster
# eps is 2.9000000000000004, minp is 23.62999999999999, one cluster
# eps is 2.9000000000000004, minp is 24.319999999999986, one cluster
# eps is 2.9000000000000004, minp is 25.009999999999984, one cluster
# eps is 2.9000000000000004, minp is 25.699999999999985, one cluster
# eps is 3.0000000000000004, minp is 5.0, one cluster
# eps is 3.0000000000000004, minp is 5.6899999999999995, one cluster
# eps is 3.0000000000000004, minp is 6.379999999999999, one cluster
# eps is 3.0000000000000004, minp is 7.0699999999999985, one cluster
# eps is 3.0000000000000004, minp is 7.759999999999998, one cluster
# eps is 3.0000000000000004, minp is 8.449999999999998, one cluster
# eps is 3.0000000000000004, minp is 9.139999999999997, one cluster
# eps is 3.0000000000000004, minp is 9.829999999999997, one cluster
# eps is 3.0000000000000004, minp is 10.519999999999996, one cluster
# eps is 3.0000000000000004, minp is 11.209999999999996, one cluster
# eps is 3.0000000000000004, minp is 11.899999999999995, one cluster
# eps is 3.0000000000000004, minp is 12.589999999999995, one cluster
# eps is 3.0000000000000004, minp is 13.279999999999994, one cluster
# eps is 3.0000000000000004, minp is 13.969999999999994, one cluster
# eps is 3.0000000000000004, minp is 14.659999999999993, one cluster
# eps is 3.0000000000000004, minp is 15.349999999999993, one cluster
# eps is 3.0000000000000004, minp is 16.039999999999992, one cluster
# eps is 3.0000000000000004, minp is 16.72999999999999, one cluster
# eps is 3.0000000000000004, minp is 17.41999999999999, one cluster
# eps is 3.0000000000000004, minp is 18.109999999999992, one cluster
# eps is 3.0000000000000004, minp is 18.79999999999999, one cluster
# eps is 3.0000000000000004, minp is 19.489999999999988, one cluster
# eps is 3.0000000000000004, minp is 20.17999999999999, one cluster
# eps is 3.0000000000000004, minp is 20.86999999999999, one cluster
# eps is 3.0000000000000004, minp is 21.559999999999988, one cluster
# eps is 3.0000000000000004, minp is 22.249999999999986, one cluster
# eps is 3.0000000000000004, minp is 22.939999999999987, one cluster
# eps is 3.0000000000000004, minp is 23.62999999999999, one cluster
# eps is 3.0000000000000004, minp is 24.319999999999986, one cluster
# eps is 3.0000000000000004, minp is 25.009999999999984, one cluster
# eps is 3.0000000000000004, minp is 25.699999999999985, one cluster

# %%
coords = dftot[['col1', 'col2']]
ss = StandardScaler()
coords = ss.fit_transform(coords)
db = DBSCAN(eps=0.3, min_samples=23)
#0.21,7
#0.3,23
db.fit(coords)
y_pred = db.fit_predict(coords)
plt.scatter(coords[:, 0], coords[:, 1], c=y_pred, cmap='Paired',s=20)
plt.title("DBSCAN")
plt.show()

# %% [markdown]
# ### Gaussian Mixture
# * Use GaussianMixture function to cluster the above data
# * In GMM change the covariance_type and check the difference in the resulting proabability fit
# * Use a 2D contour plot to plot the resulting distribution (the components of the GMM) as well as the total Gaussian mixture

# %%
gmm = GaussianMixture(n_components = 4)
gmm.fit(dftot[['col1', 'col2']])
clusters = gmm.predict(dftot[['col1', 'col2']])
dftot['cluster'] = clusters

plt.scatter(x=dftot["col1"], y=dftot["col2"],s=20, c=dftot["cluster"])
plt.show()

# %% [markdown]
# ## iris data set
# The iris data set is test data set that is part of the Sklearn module
# which contains 150 records each with 4 features. All the features are represented by real numbers
#
# The data represents three classes

# %%
from sklearn.datasets import load_iris
iris_data = load_iris()
iris_data.target[[10, 25, 50]]
#array([0, 0, 1])
list(iris_data.target_names)
['setosa', 'versicolor', 'virginica']
# Out:
# ['setosa', 'versicolor', 'virginica']

# %% [markdown]
# * Repeat all the above clustering approaches and steps on the above data
# * Normalize the data then repeat all the above steps
# * Compare between the different clustering approaches

# %% [markdown]
# ## Customer dataset
# Repeat all the above on the customer data set
